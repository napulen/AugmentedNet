# %%
from common import ANNOTATIONSCOREMAP
import music21

# %%
for annotation, score in ANNOTATIONSCOREMAP.items():
    s = music21.converter.parse(score)
    incompleteMeasures = []
    for offset, measures in s.measureOffsetMap().items():
        m = measures[0]
        barDurationProportion = m.barDurationProportion()
        if barDurationProportion != 1.0:
            incompleteMeasures.append(m.number)
#             print(offset, m, barDurationProportion)
    if incompleteMeasures:
        print(score, incompleteMeasures)
# Out:
# functional-harmony-micchi/data/BPS/scores/bps_01_01.mxl [0, 48, 48, 152]
# functional-harmony-micchi/data/BPS/scores/bps_02_01.mxl [0, 43, 44, 45, 76, 78, 85, 86, 87, 88, 102, 103, 104, 142, 143, 156, 157, 160, 165, 263, 264, 304, 305, 307, 336]
# functional-harmony-micchi/data/BPS/scores/bps_06_01.mxl [0, 202]
# functional-harmony-micchi/data/BPS/scores/bps_07_01.mxl [0, 344]
# functional-harmony-micchi/data/BPS/scores/bps_10_01.mxl [0, 200]
# functional-harmony-micchi/data/BPS/scores/bps_11_01.mxl [0, 37, 51, 52, 53, 124, 183]
# functional-harmony-micchi/data/BPS/scores/bps_12_01.mxl [0]
# functional-harmony-micchi/data/BPS/scores/bps_16_01.mxl [0, 325]
# functional-harmony-micchi/data/BPS/scores/bps_17_01.mxl [25, 32, 34, 36, 54, 55, 56, 87, 88, 89, 90, 91, 92, 134, 135, 136, 137, 138, 139, 140, 141, 142, 184, 185, 186]
# functional-harmony-micchi/data/BPS/scores/bps_19_01.mxl [0, 110]
# functional-harmony-micchi/data/BPS/scores/bps_21_01.mxl [1, 2, 5, 6, 49, 141, 142, 143, 144, 145, 156, 157, 160, 161, 211, 249, 250, 277, 278, 285, 293, 294]
# functional-harmony-micchi/data/BPS/scores/bps_22_01.mxl [0, 154]
# functional-harmony-micchi/data/BPS/scores/bps_23_01.mxl [0]
# functional-harmony-micchi/data/BPS/scores/bps_27_01.mxl [0, 15, 34, 66, 68, 72, 158, 177, 209, 215]
# functional-harmony-micchi/data/BPS/scores/bps_28_01.mxl [99]
# functional-harmony-micchi/data/BPS/scores/bps_29_01.mxl [0, 395, 396, 401, 402]
# functional-harmony-micchi/data/BPS/scores/bps_30_01.mxl [0, 91, 101]
# functional-harmony-micchi/data/BPS/scores/bps_32_01.mxl [0]
# When-in-Rome/Corpus/OpenScore-LiederCorpus/Hensel,_Fanny_(Mendelssohn)/6_Lieder,_Op.1/3_Warum_sind_denn_die_Rosen_so_blass/score.mxl [0]
# When-in-Rome/Corpus/OpenScore-LiederCorpus/Hensel,_Fanny_(Mendelssohn)/6_Lieder,_Op.9/5_Der_Maiabend/score.mxl [0]
# When-in-Rome/Corpus/OpenScore-LiederCorpus/Hensel,_Fanny_(Mendelssohn)/5_Lieder,_Op.10/5_Bergeslust/score.mxl [1]
# When-in-Rome/Corpus/OpenScore-LiederCorpus/Schumann,_Clara/6_Lieder,_Op.13/3_Liebeszauber/score.mxl [0]
# When-in-Rome/Corpus/OpenScore-LiederCorpus/Schumann,_Clara/6_Lieder,_Op.23/4_Auf_einem_grünen_Hügel/score.mxl [0]
# When-in-Rome/Corpus/OpenScore-LiederCorpus/Schumann,_Clara/_/Die_gute_Nacht/score.mxl [0]
# When-in-Rome/Corpus/OpenScore-LiederCorpus/Franz,_Robert/6_Gesänge,_Op.14/5_Liebesfrühling/score.mxl [0, 26]
# When-in-Rome/Corpus/OpenScore-LiederCorpus/Wolf,_Hugo/Eichendorff-Lieder/14_Der_verzweifelte_Liebhaber/score.mxl [0]
# When-in-Rome/Corpus/OpenScore-LiederCorpus/Wolf,_Hugo/Eichendorff-Lieder/20_Waldmädchen/score.mxl [0]
# When-in-Rome/Corpus/OpenScore-LiederCorpus/Wolf,_Hugo/Eichendorff-Lieder/15_Unfall/score.mxl [1]
# When-in-Rome/Corpus/OpenScore-LiederCorpus/Mahler,_Gustav/Kindertotenlieder/4_Oft_denk’_ich,_sie_sind_nur_ausgegangen/score.mxl [0]
# When-in-Rome/Corpus/OpenScore-LiederCorpus/Schumann,_Robert/Frauenliebe_und_Leben,_Op.42/3_Ich_kann’s_nicht_fassen/score.mxl [0]
# When-in-Rome/Corpus/OpenScore-LiederCorpus/Schumann,_Robert/Dichterliebe,_Op.48

# functional-harmony-micchi/data/Tavern/Beethoven/scores/B072.mxl [0, 32, 32, 64, 64, 96, 96, 128, 128, 160, 160, 192, 192, 224, 224, 256, 256]
# functional-harmony-micchi/data/Tavern/Beethoven/scores/B073.mxl [166]
# functional-harmony-micchi/data/Tavern/Beethoven/scores/B073.mxl [166]
# functional-harmony-micchi/data/Tavern/Beethoven/scores/B075.mxl [0, 49, 49, 98, 98, 147, 147, 196, 196, 245, 245, 294, 294, 343, 343]
# functional-harmony-micchi/data/Tavern/Beethoven/scores/B075.mxl [0, 49, 49, 98, 98, 147, 147, 196, 196, 245, 245, 294, 294, 343, 343]
# functional-harmony-micchi/data/Tavern/Beethoven/scores/B077.mxl [0, 16, 16, 32, 32, 48, 48, 72, 72, 88, 88, 104, 104]
# functional-harmony-micchi/data/Tavern/Beethoven/scores/B077.mxl [0, 16, 16, 32, 32, 48, 48, 72, 72, 88, 88, 104, 104]
# functional-harmony-micchi/data/Tavern/Beethoven/scores/B078.mxl [84, 84]
# functional-harmony-micchi/data/Tavern/Beethoven/scores/B078.mxl [84, 84]
# functional-harmony-micchi/data/Tavern/Mozart/scores/K025.mxl [0, 18, 18, 36, 36, 54, 54, 72, 72, 90, 90, 108, 108, 126, 126, 144]
# functional-harmony-micchi/data/Tavern/Mozart/scores/K025.mxl [0, 18, 18, 36, 36, 54, 54, 72, 72, 90, 90, 108, 108, 126, 126, 144]
# functional-harmony-micchi/data/Tavern/Mozart/scores/K353.mxl [0, 108, 108, 120, 120, 144, 173, 183]
# functional-harmony-micchi/data/Tavern/Mozart/scores/K353.mxl [0, 108, 108, 120, 120, 144, 173, 183]
# functional-harmony-micchi/data/Tavern/Mozart/scores/K501.mxl [0]
# functional-harmony-micchi/data/Tavern/Mozart/scores/K501.mxl [0]
# functional-harmony-micchi/data/Tavern/Mozart/scores/K613.mxl [0]
# functional-harmony-micchi/data/Tavern/Mozart/scores/K613.mxl [0]
# ---------------------------------------------------------------------------
# ConverterFileException                    Traceback (most recent call last)
# <ipython-input-2-304dc543b369> in <module>
#       1 for annotation, score in ANNOTATIONSCOREMAP.items():
# ----> 2     s = music21.converter.parse(score)
#       3     incompleteMeasures = []
#       4     for offset, measures in s.measureOffsetMap().items():
#       5         m = measures[0]
#
# ~/.local/lib/python3.8/site-packages/music21/converter/__init__.py in parse(value, *args, **keywords)
#    1166     elif (not isinstance(value, bytes)
#    1167           and _osCanLoad(valueStr)):
# -> 1168         return parseFile(valueStr, number=number, format=m21Format,
#    1169                          forceSource=forceSource, **keywords)
#    1170     elif (not isinstance(value, bytes)
#
# ~/.local/lib/python3.8/site-packages/music21/converter/__init__.py in parseFile(fp, number, format, forceSource, **keywords)
#    1025     v = Converter()
#    1026     fp = common.cleanpath(fp, returnPathlib=True)
# -> 1027     v.parseFile(fp, number=number, format=format, forceSource=forceSource, **keywords)
#    1028     return v.stream
#    1029
#
# ~/.local/lib/python3.8/site-packages/music21/converter/__init__.py in parseFile(self, fp, number, format, forceSource, storePickle, **keywords)
#     546
#     547         if useFormat is None:
# --> 548             useFormat = self.getFormatFromFileExtension(fp)
#     549
#     550         pfObj = PickleFilter(fp, forceSource, number, **keywords)
#
# ~/.local/lib/python3.8/site-packages/music21/converter/__init__.py in getFormatFromFileExtension(self, fp)
#     524             useFormat = common.findFormatFile(fp)
#     525             if useFormat is None:
# --> 526                 raise ConverterFileException(f'cannot find a format extensions for: {fp}')
#     527         return useFormat
#     528
#
# ConverterFileException: cannot find a format extensions for: /home/napulen/dev/AugmentedNet/ABC/data/mscx/op. 18 No. 1/op18_no1_mov1.mscx
